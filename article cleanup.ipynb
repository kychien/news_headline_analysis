# %% [markdown]
# # Headline Classifier and Cleanup

# %%
# Set up and dependencies
from pprint import pprint
import pandas as pd
import numpy as np
import re

# %%
# Load source file and preview
headlines = pd.read_csv('articles1.csv')
headlines.head()
# Out:
#    Unnamed: 0     id                                              title  \
# 0           0  17283  House Republicans Fret About Winning Their Hea...
# 1           1  17284  Rift Between Officers and Residents as Killing...
# 2           2  17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3           3  17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4           4  17287  Kim Jong-un Says North Korea Is Preparing to T...
#
#       publication                         author        date    year  month  \
# 0  New York Times                     Carl Hulse  2016-12-31  2016.0   12.0
# 1  New York Times  Benjamin Mueller and Al Baker  2017-06-19  2017.0    6.0
# 2  New York Times                   Margalit Fox  2017-01-06  2017.0    1.0
# 3  New York Times               William McDonald  2017-04-10  2017.0    4.0
# 4  New York Times                  Choe Sang-Hun  2017-01-02  2017.0    1.0
#
#    url                                            content
# 0  NaN  WASHINGTON  —   Congressional Republicans have...
# 1  NaN  After the bullet shells get counted, the blood...
# 2  NaN  When Walt Disney’s “Bambi” opened in 1942, cri...
# 3  NaN  Death may be the great equalizer, but it isn’t...
# 4  NaN  SEOUL, South Korea  —   North Korea’s leader, ...

# %%
headlines.columns
# Out:
# Index(['Unnamed: 0', 'id', 'title', 'publication', 'author', 'date', 'year',
#        'month', 'url', 'content'],
#       dtype='object')

# %%
headlines.drop(['Unnamed: 0', 'id', 'author', 'date', 'year', 'month', 'url', 'content'],
               axis=1, inplace=True)
headlines.head()
# Out:
#                                                title     publication
# 0  House Republicans Fret About Winning Their Hea...  New York Times
# 1  Rift Between Officers and Residents as Killing...  New York Times
# 2  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...  New York Times
# 3  Among Deaths in 2016, a Heavy Toll in Pop Musi...  New York Times
# 4  Kim Jong-un Says North Korea Is Preparing to T...  New York Times

# %%
headlines.to_csv('article1_stripped.csv', index=False)

# %%
# Examine headlines for potential issues
for ind, row in headlines.head(25).iterrows():
    print(row['title'])
# Out:
# House Republicans Fret About Winning Their Health Care Suit - The New York Times
# Rift Between Officers and Residents as Killings Persist in South Bronx - The New York Times
# Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial Bias, Dies at 106 - The New York Times
# Among Deaths in 2016, a Heavy Toll in Pop Music - The New York Times
# Kim Jong-un Says North Korea Is Preparing to Test Long-Range Missile - The New York Times
# Sick With a Cold, Queen Elizabeth Misses New Year’s Service - The New York Times
# Taiwan’s President Accuses China of Renewed Intimidation - The New York Times
# After ‘The Biggest Loser,’ Their Bodies Fought to Regain Weight - The New York Times
# First, a Mixtape. Then a Romance. - The New York Times
# Calling on Angels While Enduring the Trials of Job - The New York Times
# Weak Federal Powers Could Limit Trump’s Climate-Policy Rollback - The New York Times
# Can Carbon Capture Technology Prosper Under Trump? - The New York Times
# Mar-a-Lago, the Future Winter White House and Home of the Calmer Trump - The New York Times
# How to form healthy habits in your 20s - The New York Times
# Turning Your Vacation Photos Into Works of Art - The New York Times
# As Second Avenue Subway Opens, a Train Delay Ends in (Happy) Tears - The New York Times
# Dylann Roof Himself Rejects Best Defense Against Execution - The New York Times
# Modi’s Cash Ban Brings Pain, but Corruption-Weary India Grits Its Teeth - The New York Times
# Suicide Bombing in Baghdad Kills at Least 36 - The New York Times
# Fecal Pollution Taints Water at Melbourne’s Beaches After Storm - The New York Times
# N.F.L. Playoffs: Schedule, Matchups and Odds - The New York Times
# Mariah Carey’s Manager Blames Producers for New Year’s Eve Nightmare - The New York Times
# Damaged by War, Syria’s Cultural Sites Rise Anew in France - The New York Times
# George Michael’s Freedom Video: An Oral History - The New York Times
# With New Congress Poised to Convene, Obama’s Policies Are in Peril - The New York Times

# %%
print(len(headlines))
headlines.dropna(inplace=True)
print(len(headlines))
# Out:
# 50000
# 50000

# %%
headlines.drop_duplicates(inplace=True)
print(len(headlines))
# Out:
# 49920

# %%
headlines = headlines.loc[headlines['title'] != 'SIGN IN']
print(len(headlines))
# Out:
# 49919

# %%
def titleToHeadline(row):
    text = str(row['title'])
    text = text.replace(' - The New York Times',   '')
    text = text.replace(' - Breitbart',   '')
    text = text.replace('U.S.', 'USAAbbrev')
    return text.lower()

all_publishers = ['CNN',
                  #'Huffington Post',
                  'Vox', 
                  'Atlantic', 
                  'Business Insider', 
                  'Buzzfeed News', 
                  'Guardian', 
                  'NPR', 
                  'New York Times', 
                  'Reuters', 
                  'Talking Points Memo', 
                  'Washington Post', 
                  'New York Post',
                  'Daily Wire',
                  'Fox News', 
                  'National Review',
                  'Breitbart']

ll = ['CNN', 'Vox']
lc = ['Atlantic', 'Business Insider', 'Buzzfeed News', 'Guardian', 'NPR', 
      'New York Times', 'Reuters', 'Talking Points Memo', 'Washington Post']
rc = ['New York Post', 'WSJ']
rr = ['Daily Wire', 'Fox News', 'National Review']


def addBias(row):
    
    pub_name = str(row['publication'])
    
    if (pub_name in ll):
        return "LL"
    elif (pub_name in lc):
        return "LC"
    elif (pub_name in rc):
        return "RC"
    elif (pub_name in rr):
        return "RR"
    
    return "NA"

def simpleBias(row):
    return str(row['bias'])[0]

def punctuationToText(row):
    text = str(row['headline'])
    text = text.replace(',',   ' pcomma')
    text = text.replace('.',   ' pperiod ')
    text = text.replace('!',   ' pexclamation')
    text = text.replace('?',   ' pquestion')
    text = text.replace(" '",  ' pquote ')
    text = text.replace(" ‘",  ' pquote ')
    text = text.replace("'s ", ' ppossession ')
    text = text.replace("’s ", ' ppossession ')
    text = text.replace("'",   '')
    text = text.replace("’",   '')
    text = text.replace("(",   ' pparen ')
    text = text.replace(")",   '')
    text = text.replace(':',   ' pcolon')
    text = text.replace(';',   ' psemic')
    text = text.replace('-',   ' pdash ')
    text = text.replace('  ',   ' ')
    return text

# %%
headlines['headline'] = headlines.apply(titleToHeadline, axis=1)
for ind, row in headlines.head(25).iterrows():
    print(row['headline'])
# Out:
# house republicans fret about winning their health care suit
# rift between officers and residents as killings persist in south bronx
# tyrus wong, ‘bambi’ artist thwarted by racial bias, dies at 106
# among deaths in 2016, a heavy toll in pop music
# kim jong-un says north korea is preparing to test long-range missile
# sick with a cold, queen elizabeth misses new year’s service
# taiwan’s president accuses china of renewed intimidation
# after ‘the biggest loser,’ their bodies fought to regain weight
# first, a mixtape. then a romance.
# calling on angels while enduring the trials of job
# weak federal powers could limit trump’s climate-policy rollback
# can carbon capture technology prosper under trump?
# mar-a-lago, the future winter white house and home of the calmer trump
# how to form healthy habits in your 20s
# turning your vacation photos into works of art
# as second avenue subway opens, a train delay ends in (happy) tears
# dylann roof himself rejects best defense against execution
# modi’s cash ban brings pain, but corruption-weary india grits its teeth
# suicide bombing in baghdad kills at least 36
# fecal pollution taints water at melbourne’s beaches after storm
# n.f.l. playoffs: schedule, matchups and odds
# mariah carey’s manager blames producers for new year’s eve nightmare
# damaged by war, syria’s cultural sites rise anew in france
# george michael’s freedom video: an oral history
# with new congress poised to convene, obama’s policies are in peril

# %%
headlines.to_csv('article1_clean.csv', index=False)

# %% [markdown]
# ### Function Based Cleanup

# %%
def stripClean(filename):
    headlines = pd.read_csv(filename)
    headlines.drop(['Unnamed: 0', 'id', 'author', 'date', 'year', 'month', 'url', 'content'], 
                   axis=1, inplace=True)
    #headlines.to_csv('_stripped.'.join(filename.split('.')), index=False)
    startsize = len(headlines)
    headlines.dropna(inplace=True)
    headlines.drop_duplicates(inplace=True)
    headlines = headlines.loc[headlines['title'] != 'SIGN IN']
    headlines['headline'] = headlines.apply(titleToHeadline, axis=1)
    headlines['bias'] = headlines.apply(addBias, axis=1)
    headlines['lean'] = headlines.apply(simpleBias, axis=1)
    headlines['is_sarcastic'] = 0
    headlines['head_char'] = headlines.apply(punctuationToText, axis=1)
    headlines.to_csv('_clean.'.join(filename.split('.')), index=False)
    print(f'{len(headlines)}/{startsize} rows in {filename} were kept.')
    return headlines

def noStripClean(filename):
    headlines = pd.read_csv(filename)
    startsize = len(headlines)
    headlines.dropna(inplace=True)
    headlines.drop_duplicates(inplace=True)
    headlines = headlines.loc[headlines['title'] != 'SIGN IN']
    headlines['headline'] = headlines.apply(titleToHeadline, axis=1)
    headlines['bias'] = headlines.apply(addBias, axis=1)
    headlines['lean'] = headlines.apply(simpleBias, axis=1)
    headlines['is_sarcastic'] = 0
    headlines['head_char'] = headlines.apply(punctuationToText, axis=1)
    headlines.to_csv('_clean.'.join(filename.split('.')), index=False)
    print(f'{len(headlines)}/{startsize} rows in {filename} were kept.')
    return headlines

# %%
set1 = stripClean('articles1.csv')
set2 = stripClean('articles2.csv')
set3 = stripClean('articles3.csv')
# Out:
# 49919/50000 rows in articles1.csv were kept.
# 49664/49999 rows in articles2.csv were kept.
# 42553/42571 rows in articles3.csv were kept.

# %%
for ind, row in set1.head(25).iterrows():
    print(row['head_char'])
# Out:
# house republicans fret about winning their health care suit
# rift between officers and residents as killings persist in south bronx
# tyrus wong pcomma pquote bambi artist thwarted by racial bias pcomma dies at 106
# among deaths in 2016 pcomma a heavy toll in pop music
# kim jong pdash un says north korea is preparing to test long pdash range missile
# sick with a cold pcomma queen elizabeth misses new year ppossession service
# taiwan ppossession president accuses china of renewed intimidation
# after pquote the biggest loser pcomma their bodies fought to regain weight
# first pcomma a mixtape pperiod then a romance pperiod
# calling on angels while enduring the trials of job
# weak federal powers could limit trump ppossession climate pdash policy rollback
# can carbon capture technology prosper under trump pquestion
# mar pdash a pdash lago pcomma the future winter white house and home of the calmer trump
# how to form healthy habits in your 20s
# turning your vacation photos into works of art
# as second avenue subway opens pcomma a train delay ends in pparen happy tears
# dylann roof himself rejects best defense against execution
# modi ppossession cash ban brings pain pcomma but corruption pdash weary india grits its teeth
# suicide bombing in baghdad kills at least 36
# fecal pollution taints water at melbourne ppossession beaches after storm
# n pperiod f pperiod l pperiod playoffs pcolon schedule pcomma matchups and odds
# mariah carey ppossession manager blames producers for new year ppossession eve nightmare
# damaged by war pcomma syria ppossession cultural sites rise anew in france
# george michael ppossession freedom video pcolon an oral history
# with new congress poised to convene pcomma obama ppossession policies are in peril

# %%
set4 = noStripClean('daily_wire_small.csv')
# Out:
# 1472/1477 rows in daily_wire_small.csv were kept.

# %%
set4.head()
# Out:
#                                                title publication  \
# 0  Make the web’s best conservative commentary ev...  Daily Wire
# 1  Bipartisan Support Builds For Israeli Sovereig...  Daily Wire
# 2  Shapiro At 'National Review': A World Without ...  Daily Wire
# 3  Limbaugh: As These Sex Scandals Hit Democrats,...  Daily Wire
# 4  VA Gov. Northam: I Won't Resign And Be Branded...  Daily Wire
#
#                                             headline bias lean  is_sarcastic  \
# 0  make the web’s best conservative commentary ev...   RR    R             0
# 1  bipartisan support builds for israeli sovereig...   RR    R             0
# 2  shapiro at 'national review': a world without ...   RR    R             0
# 3  limbaugh: as these sex scandals hit democrats,...   RR    R             0
# 4  va gov. northam: i won't resign and be branded...   RR    R             0
#
#                                            head_char
# 0  make the web ppossession best conservative com...
# 1  bipartisan support builds for israeli sovereig...
# 2  shapiro at pquote national review pcolon a wor...
# 3  limbaugh pcolon as these sex scandals hit demo...
# 4  va gov pperiod northam pcolon i wont resign an...

# %%
headlines = pd.concat([set1, set2, set3, set4])
print(len(headlines))
headlines.head(5)
# Out:
# 143608
#                                                title     publication  \
# 0  House Republicans Fret About Winning Their Hea...  New York Times
# 1  Rift Between Officers and Residents as Killing...  New York Times
# 2  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...  New York Times
# 3  Among Deaths in 2016, a Heavy Toll in Pop Musi...  New York Times
# 4  Kim Jong-un Says North Korea Is Preparing to T...  New York Times
#
#                                             headline bias lean  is_sarcastic  \
# 0  house republicans fret about winning their hea...   LC    L             0
# 1  rift between officers and residents as killing...   LC    L             0
# 2  tyrus wong, ‘bambi’ artist thwarted by racial ...   LC    L             0
# 3    among deaths in 2016, a heavy toll in pop music   LC    L             0
# 4  kim jong-un says north korea is preparing to t...   LC    L             0
#
#                                            head_char
# 0  house republicans fret about winning their hea...
# 1  rift between officers and residents as killing...
# 2  tyrus wong pcomma pquote bambi artist thwarted...
# 3  among deaths in 2016 pcomma a heavy toll in po...
# 4  kim jong pdash un says north korea is preparin...

# %%
headlines.columns
# Out:
# Index(['title', 'publication', 'headline', 'bias', 'lean', 'is_sarcastic',
#        'head_char'],
#       dtype='object')

# %%
sep_headlines = []
for publisher in all_publishers:
    selectset = headlines.loc[headlines['publication'] == publisher]
    savename = publisher + '_headlines.csv'
    selectset.to_csv(savename, index=False)
    print(f'Saved {savename}!')
    sep_headlines.append(selectset)
# Out:
# Saved CNN_headlines.csv!
# Saved Vox_headlines.csv!
# Saved Atlantic_headlines.csv!
# Saved Business Insider_headlines.csv!
# Saved Buzzfeed News_headlines.csv!
# Saved Guardian_headlines.csv!
# Saved NPR_headlines.csv!
# Saved New York Times_headlines.csv!
# Saved Reuters_headlines.csv!
# Saved Talking Points Memo_headlines.csv!
# Saved Washington Post_headlines.csv!
# Saved New York Post_headlines.csv!
# Saved Daily Wire_headlines.csv!
# Saved Fox News_headlines.csv!
# Saved National Review_headlines.csv!
# Saved Breitbart_headlines.csv!

# %%
headlines['publication'].unique()
# Out:
# array(['New York Times', 'Breitbart', 'CNN', 'Business Insider',
#        'Atlantic', 'Fox News', 'Talking Points Memo', 'Buzzfeed News',
#        'National Review', 'New York Post', 'Guardian', 'NPR', 'Reuters',
#        'Vox', 'Washington Post', 'Daily Wire'], dtype=object)

# %%
for df in sep_headlines:
    print(df.head())
# Out:
#                                                  title publication  \
# 31584      Istanbul attack: Dozens killed at nightclub         CNN
# 31585     Alabama, Clemson back in national title game         CNN
# 31586               New year celebrations ring in 2017         CNN
# 31587  Trump says he has inside information on hacking         CNN
# 31588            3 dead in Texas plane crash collision         CNN
#
#                                               headline bias lean  \
# 31584      istanbul attack: dozens killed at nightclub   LL    L
# 31585     alabama, clemson back in national title game   LL    L
# 31586               new year celebrations ring in 2017   LL    L
# 31587  trump says he has inside information on hacking   LL    L
# 31588            3 dead in texas plane crash collision   LL    L
#
#        is_sarcastic                                          head_char
# 31584             0  istanbul attack pcolon dozens killed at nightclub
# 31585             0  alabama pcomma clemson back in national title ...
# 31586             0                 new year celebrations ring in 2017
# 31587             0    trump says he has inside information on hacking
# 31588             0              3 dead in texas plane crash collision
#                                                    title publication  \
# 26510  Why Google co-founder Larry Page is pouring mi...         Vox
# 26511  President Obama just took unprecedented steps ...         Vox
# 26512  The DNC race has become another fight over Ber...         Vox
# 26513  A simple guide to CRISPR, one of the biggest s...         Vox
# 26514  I quit alcohol to save my life. But I miss the...         Vox
#
#                                                 headline bias lean  \
# 26510  why google co-founder larry page is pouring mi...   LL    L
# 26511  president obama just took unprecedented steps ...   LL    L
# 26512  the dnc race has become another fight over ber...   LL    L
# 26513  a simple guide to crispr, one of the biggest s...   LL    L
# 26514  i quit alcohol to save my life. but i miss the...   LL    L
#
#        is_sarcastic                                          head_char
# 26510             0  why google co pdash founder larry page is pour...
# 26511             0  president obama just took unprecedented steps ...
# 26512             0  the dnc race has become another fight over ber...
# 26513             0  a simple guide to crispr pcomma one of the big...
# 26514             0  i quit alcohol to save my life pperiod but i m...
#                                                    title publication  \
# 49829  Obama: Reaching Out to Adversaries, Alienating...    Atlantic
# 49830  George Michael and Carrie Fisher: The Week in ...    Atlantic
# 49831                                 The New Reality TV    Atlantic
# 49832           5 Numbers That Explain Education in 2016    Atlantic
# 49833  The Atlantic  Politics & Policy Daily: Happy G...    Atlantic
#
#                                                 headline bias lean  \
# 49829  obama: reaching out to adversaries, alienating...   LC    L
# 49830  george michael and carrie fisher: the week in ...   LC    L
# 49831                                 the new reality tv   LC    L
# 49832           5 numbers that explain education in 2016   LC    L
# 49833  the atlantic  politics & policy daily: happy g...   LC    L
#
#        is_sarcastic                                          head_char
# 49829             0  obama pcolon reaching out to adversaries pcomm...
# 49830             0  george michael and carrie fisher pcolon the we...
# 49831             0                                 the new reality tv
# 49832             0           5 numbers that explain education in 2016
# 49833             0  the atlantic politics & policy daily pcolon ha...
#                                                    title       publication  \
# 43072  Trump focuses New Year’s tweet on ’many enemie...  Business Insider
# 43073  Google and Google Home promote fake news story...  Business Insider
# 43074        Vermont utility targeted by Russian hackers  Business Insider
# 43075  UN Security Council welcomes Russo-Turkish bro...  Business Insider
# 43076  A giant wave of store closures is about to hit...  Business Insider
#
#                                                 headline bias lean  \
# 43072  trump focuses new year’s tweet on ’many enemie...   LC    L
# 43073  google and google home promote fake news story...   LC    L
# 43074        vermont utility targeted by russian hackers   LC    L
# 43075  un security council welcomes russo-turkish bro...   LC    L
# 43076  a giant wave of store closures is about to hit...   LC    L
#
#        is_sarcastic                                          head_char
# 43072             0  trump focuses new year ppossession tweet on ma...
# 43073             0  google and google home promote fake news story...
# 43074             0        vermont utility targeted by russian hackers
# 43075             0  un security council welcomes russo pdash turki...
# 43076             0  a giant wave of store closures is about to hit...
#                                                    title    publication  \
# 16576   Meet The Gay Couple Featured On The Walls Of ...  Buzzfeed News
# 16577           California’s First Dog, Sutter, Has Died  Buzzfeed News
# 16578   Chicago Had More Homicides In 2016 Than New Y...  Buzzfeed News
# 16579   Ford Abandons Plan For $1.6 Billion Mexico Fa...  Buzzfeed News
# 16580   Donald Trump’s Twitter Account Is A Security ...  Buzzfeed News
#
#                                                 headline bias lean  \
# 16576   meet the gay couple featured on the walls of ...   LC    L
# 16577           california’s first dog, sutter, has died   LC    L
# 16578   chicago had more homicides in 2016 than new y...   LC    L
# 16579   ford abandons plan for $1.6 billion mexico fa...   LC    L
# 16580   donald trump’s twitter account is a security ...   LC    L
#
#        is_sarcastic                                          head_char
# 16576             0   meet the gay couple featured on the walls of ...
# 16577             0   california ppossession first dog pcomma sutte...
# 16578             0   chicago had more homicides in 2016 than new y...
# 16579             0   ford abandons plan for $1 pperiod 6 billion m...
# 16580             0   donald trump ppossession twitter account is a...
#                                                    title publication  \
# 45126  Donald Trump may pose an existential threat to...    Guardian
# 45127  Steph Curry’s vanity project is a kick in the ...    Guardian
# 45128  Sign up for the Minute: the day in US politics...    Guardian
# 45129  Kangaroo pictures found at RCS may be Australi...    Guardian
# 45130  The best player from every Premier League club...    Guardian
#
#                                                 headline bias lean  \
# 45126  donald trump may pose an existential threat to...   LC    L
# 45127  steph curry’s vanity project is a kick in the ...   LC    L
# 45128  sign up for the minute: the day in us politics...   LC    L
# 45129  kangaroo pictures found at rcs may be australi...   LC    L
# 45130  the best player from every premier league club...   LC    L
#
#        is_sarcastic                                          head_char
# 45126             0  donald trump may pose an existential threat to...
# 45127             0  steph curry ppossession vanity project is a ki...
# 45128             0  sign up for the minute pcolon the day in us po...
# 45129             0  kangaroo pictures found at rcs may be australi...
# 45130             0  the best player from every premier league club...
#                                                   title publication  \
# 3808  Thanks To Russia, 2016 Isn’t Really Going To E...         NPR
# 3809  Trump Tweets Give A Glimpse Into Foreign Polic...         NPR
# 3810  As U.S. Confronts Russia, Trump’s Admiration O...         NPR
# 3811  Putin Says Russia Won’t Expel Diplomats In Res...         NPR
# 3812      (Some Of) Our Favorite Visual Stories of 2016         NPR
#
#                                                headline bias lean  \
# 3808  thanks to russia, 2016 isn’t really going to e...   LC    L
# 3809  trump tweets give a glimpse into foreign polic...   LC    L
# 3810  as usaabbrev confronts russia, trump’s admirat...   LC    L
# 3811  putin says russia won’t expel diplomats in res...   LC    L
# 3812      (some of) our favorite visual stories of 2016   LC    L
#
#       is_sarcastic                                          head_char
# 3808             0  thanks to russia pcomma 2016 isnt really going...
# 3809             0  trump tweets give a glimpse into foreign polic...
# 3810             0  as usaabbrev confronts russia pcomma trump ppo...
# 3811             0  putin says russia wont expel diplomats in resp...
# 3812             0   pparen some of our favorite visual stories of...
#                                                title     publication  \
# 0  House Republicans Fret About Winning Their Hea...  New York Times
# 1  Rift Between Officers and Residents as Killing...  New York Times
# 2  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...  New York Times
# 3  Among Deaths in 2016, a Heavy Toll in Pop Musi...  New York Times
# 4  Kim Jong-un Says North Korea Is Preparing to T...  New York Times
#
#                                             headline bias lean  is_sarcastic  \
# 0  house republicans fret about winning their hea...   LC    L             0
# 1  rift between officers and residents as killing...   LC    L             0
# 2  tyrus wong, ‘bambi’ artist thwarted by racial ...   LC    L             0
# 3    among deaths in 2016, a heavy toll in pop music   LC    L             0
# 4  kim jong-un says north korea is preparing to t...   LC    L             0
#
#                                            head_char
# 0  house republicans fret about winning their hea...
# 1  rift between officers and residents as killing...
# 2  tyrus wong pcomma pquote bambi artist thwarted...
# 3  among deaths in 2016 pcomma a heavy toll in po...
# 4  kim jong pdash un says north korea is preparin...
#                                                    title publication  \
# 15800  Trump praises Putin for holding back in U.S.-R...     Reuters
# 15801  Russians leave country retreats in the U.S., o...     Reuters
# 15802  Gunman kills 39 in Istanbul nightclub, manhunt...     Reuters
# 15803  New York’s Times Square erupts with cheer as a...     Reuters
# 15804  Investors brace for 2017 shocks after surprise...     Reuters
#
#                                                 headline bias lean  \
# 15800  trump praises putin for holding back in usaabb...   LC    L
# 15801  russians leave country retreats in the usaabbr...   LC    L
# 15802  gunman kills 39 in istanbul nightclub, manhunt...   LC    L
# 15803  new york’s times square erupts with cheer as a...   LC    L
# 15804  investors brace for 2017 shocks after surprise...   LC    L
#
#        is_sarcastic                                          head_char
# 15800             0  trump praises putin for holding back in usaabb...
# 15801             0  russians leave country retreats in the usaabbr...
# 15802             0  gunman kills 39 in istanbul nightclub pcomma m...
# 15803             0  new york ppossession times square erupts with ...
# 15804             0  investors brace for 2017 shocks after surprise...
#                                                    title          publication  \
# 11362  Trump Praises ’Very Smart’ Putin For ’Great Mo...  Talking Points Memo
# 11363  House Dems Vow To Fight Back Against GOP Respo...  Talking Points Memo
# 11364  Obama To Meet With Hill Dems Wednesday To Disc...  Talking Points Memo
# 11365  N.C. Guv-Elect Cooper Sues Over Elections Law ...  Talking Points Memo
# 11366                                    The Final Call!  Talking Points Memo
#
#                                                 headline bias lean  \
# 11362  trump praises ’very smart’ putin for ’great mo...   LC    L
# 11363  house dems vow to fight back against gop respo...   LC    L
# 11364  obama to meet with hill dems wednesday to disc...   LC    L
# 11365  n.c. guv-elect cooper sues over elections law ...   LC    L
# 11366                                    the final call!   LC    L
#
#        is_sarcastic                                          head_char
# 11362             0  trump praises very smart putin for great move ...
# 11363             0  house dems vow to fight back against gop respo...
# 11364             0  obama to meet with hill dems wednesday to disc...
# 11365             0  n pperiod c pperiod guv pdash elect cooper sue...
# 11366             0                        the final call pexclamation
#                                                    title      publication  \
# 31457  Inside the economic war against the Islamic State  Washington Post
# 31458  Putin won 2016, but Russia has its limits as a...  Washington Post
# 31459  Trump and Putin: A relationship where mutual a...  Washington Post
# 31460  Russian operation hacked a Vermont utility, sh...  Washington Post
# 31461  Trump’s victory was history rhyming with itsel...  Washington Post
#
#                                                 headline bias lean  \
# 31457  inside the economic war against the islamic state   LC    L
# 31458  putin won 2016, but russia has its limits as a...   LC    L
# 31459  trump and putin: a relationship where mutual a...   LC    L
# 31460  russian operation hacked a vermont utility, sh...   LC    L
# 31461  trump’s victory was history rhyming with itsel...   LC    L
#
#        is_sarcastic                                          head_char
# 31457             0  inside the economic war against the islamic state
# 31458             0  putin won 2016 pcomma but russia has its limit...
# 31459             0  trump and putin pcolon a relationship where mu...
# 31460             0  russian operation hacked a vermont utility pco...
# 31461             0  trump ppossession victory was history rhyming ...
#                                                    title    publication  \
# 27633  Gunman dressed as Santa Claus kills dozens at ...  New York Post
# 27634  Disney could receive $50M for Carrie Fisher’s ...  New York Post
# 27635  Alabama torments Washington with old-school fo...  New York Post
# 27636  NBC, Charter extend talks to avert midnight bl...  New York Post
# 27637  Phil Jackson bolts, Greg Bird explodes and mor...  New York Post
#
#                                                 headline bias lean  \
# 27633  gunman dressed as santa claus kills dozens at ...   RC    R
# 27634  disney could receive $50m for carrie fisher’s ...   RC    R
# 27635  alabama torments washington with old-school fo...   RC    R
# 27636  nbc, charter extend talks to avert midnight bl...   RC    R
# 27637  phil jackson bolts, greg bird explodes and mor...   RC    R
#
#        is_sarcastic                                          head_char
# 27633             0  gunman dressed as santa claus kills dozens at ...
# 27634             0  disney could receive $50m for carrie fishers d...
# 27635             0  alabama torments washington with old pdash sch...
# 27636             0  nbc pcomma charter extend talks to avert midni...
# 27637             0  phil jackson bolts pcomma greg bird explodes a...
#                                                title publication  \
# 0  Make the web’s best conservative commentary ev...  Daily Wire
# 1  Bipartisan Support Builds For Israeli Sovereig...  Daily Wire
# 2  Shapiro At 'National Review': A World Without ...  Daily Wire
# 3  Limbaugh: As These Sex Scandals Hit Democrats,...  Daily Wire
# 4  VA Gov. Northam: I Won't Resign And Be Branded...  Daily Wire
#
#                                             headline bias lean  is_sarcastic  \
# 0  make the web’s best conservative commentary ev...   RR    R             0
# 1  bipartisan support builds for israeli sovereig...   RR    R             0
# 2  shapiro at 'national review': a world without ...   RR    R             0
# 3  limbaugh: as these sex scandals hit democrats,...   RR    R             0
# 4  va gov. northam: i won't resign and be branded...   RR    R             0
#
#                                            head_char
# 0  make the web ppossession best conservative com...
# 1  bipartisan support builds for israeli sovereig...
# 2  shapiro at pquote national review pcolon a wor...
# 3  limbaugh pcolon as these sex scandals hit demo...
# 4  va gov pperiod northam pcolon i wont resign an...
#                                                   title publication  \
# 7008  Fire tears through Dubai luxury hotel near pla...    Fox News
# 7009                Top Carson campaign staffers resign    Fox News
# 7010  Democrat Martin O’Malley fails to qualify for ...    Fox News
# 7011  Brawl breaks out in GOP race, below the Trump ...    Fox News
# 7012  Donald Trump blasts Bill Clinton as ’one of th...    Fox News
#
#                                                headline bias lean  \
# 7008  fire tears through dubai luxury hotel near pla...   RR    R
# 7009                top carson campaign staffers resign   RR    R
# 7010  democrat martin o’malley fails to qualify for ...   RR    R
# 7011  brawl breaks out in gop race, below the trump ...   RR    R
# 7012  donald trump blasts bill clinton as ’one of th...   RR    R
#
#       is_sarcastic                                          head_char
# 7008             0  fire tears through dubai luxury hotel near pla...
# 7009             0                top carson campaign staffers resign
# 7010             0  democrat martin omalley fails to qualify for o...
# 7011             0  brawl breaks out in gop race pcomma below the ...
# 7012             0  donald trump blasts bill clinton as one of the...
#                                                   title      publication  \
# 21430  Does Trump Grasp the Reality of ‘Radical Islam’?  National Review
# 21431                 A New Year’s Request for the Left  National Review
# 21432                               Good Riddance, 2016  National Review
# 21433        Sinners in the Hands of an Indifferent God  National Review
# 21434         This Is the Moment for an Israeli Victory  National Review
#
#                                                headline bias lean  \
# 21430  does trump grasp the reality of ‘radical islam’?   RR    R
# 21431                 a new year’s request for the left   RR    R
# 21432                               good riddance, 2016   RR    R
# 21433        sinners in the hands of an indifferent god   RR    R
# 21434         this is the moment for an israeli victory   RR    R
#
#        is_sarcastic                                          head_char
# 21430             0  does trump grasp the reality of pquote radical...
# 21431             0        a new year ppossession request for the left
# 21432             0                          good riddance pcomma 2016
# 21433             0         sinners in the hands of an indifferent god
# 21434             0          this is the moment for an israeli victory
#                                                   title publication  \
# 7803  CNN’s Zeleny: ’Hard to Imagine’ Obama Would Ha...   Breitbart
# 7804  American Students on Spring Break Chant ’Build...   Breitbart
# 7805  Surge in ’Honour Crimes’ and Forced Marriages ...   Breitbart
# 7806       MILO Announces New Media Venture - Breitbart   Breitbart
# 7807  Jared Kushner at Center of Media Spotlight on ...   Breitbart
#
#                                                headline bias lean  \
# 7803  cnn’s zeleny: ’hard to imagine’ obama would ha...   NA    N
# 7804  american students on spring break chant ’build...   NA    N
# 7805  surge in ’honour crimes’ and forced marriages ...   NA    N
# 7806                   milo announces new media venture   NA    N
# 7807  jared kushner at center of media spotlight on ...   NA    N
#
#       is_sarcastic                                          head_char
# 7803             0  cnn ppossession zeleny pcolon hard to imagine ...
# 7804             0  american students on spring break chant build ...
# 7805             0  surge in honour crimes and forced marriages in...
# 7806             0                   milo announces new media venture
# 7807             0  jared kushner at center of media spotlight on ...

# %%
huffpo_df = pd.read_csv('Huffington Post_headlines.csv').drop(['Unnamed: 0'], axis=1)
huffpo_df.head()
# Out:
#                                                title      publication  \
# 0  former versace store clerk sues over secret 'b...  Huffington Post
# 1  the 'roseanne' revival catches up to our thorn...  Huffington Post
# 2  j.k. rowling wishes snape happy birthday in th...  Huffington Post
# 3                        advancing the world's women  Huffington Post
# 4     the fascinating case for eating lab-grown meat  Huffington Post
#
#                                             headline bias lean  is_sarcastic  \
# 0  former versace store clerk sues over secret 'b...   LL    L             0
# 1  the 'roseanne' revival catches up to our thorn...   LL    L             0
# 2  j.k. rowling wishes snape happy birthday in th...   LL    L             0
# 3                        advancing the world's women   LL    L             0
# 4     the fascinating case for eating lab-grown meat   LL    L             0
#
#                                            head_char
# 0  former versace store clerk sues over secret pq...
# 1  the pquote roseanne revival catches up to our ...
# 2  j pperiod k pperiod rowling wishes snape happy...
# 3              advancing the world ppossession women
# 4  the fascinating case for eating lab pdash grow...

# %%
onion_df = pd.read_csv('The Onion_headlines.csv').drop(['Unnamed: 0'], axis=1)
onion_df['bias'] = 'NR'
onion_df.to_csv('The Onion_headlines.csv', index=False)
onion_df.head()
# Out:
#                                                title publication  \
# 0  mom starting to fear son's web series closest ...   The Onion
# 1  boehner just wants wife to listen, not come up...   The Onion
# 2  top snake handler leaves sinking huckabee camp...   The Onion
# 3  nuclear bomb detonates during rehearsal for 's...   The Onion
# 4  cosby lawyer asks why accusers didn't come for...   The Onion
#
#                                             headline bias lean  is_sarcastic  \
# 0  mom starting to fear son's web series closest ...   NR    N             1
# 1  boehner just wants wife to listen, not come up...   NR    N             1
# 2  top snake handler leaves sinking huckabee camp...   NR    N             1
# 3  nuclear bomb detonates during rehearsal for 's...   NR    N             1
# 4  cosby lawyer asks why accusers didn't come for...   NR    N             1
#
#                                            head_char
# 0  mom starting to fear son ppossession web serie...
# 1  boehner just wants wife to listen pcomma not c...
# 2  top snake handler leaves sinking huckabee camp...
# 3  nuclear bomb detonates during rehearsal for pq...
# 4  cosby lawyer asks why accusers didnt come forw...

# %%
wsj_df = noStripClean('wsj_data.csv')
wsj_df.to_csv('WSJ_headlines.csv', index=False)
wsj_df.head()
# Out:
# 6501/6717 rows in wsj_data.csv were kept.
#                                                title publication  \
# 0        Gulfport Energy CEO Steps Down After Review         WSJ
# 1                       Corrections & Amplifications         WSJ
# 2       In Pittsburgh, Preparing to Sit Shiva for 11         WSJ
# 3  University System of Maryland Board Chairman R...         WSJ
# 4  American World War II Base Will Be Rebuilt as ...         WSJ
#
#                                             headline bias lean  is_sarcastic  \
# 0        gulfport energy ceo steps down after review   RC    R             0
# 1                       corrections & amplifications   RC    R             0
# 2       in pittsburgh, preparing to sit shiva for 11   RC    R             0
# 3  university system of maryland board chairman r...   RC    R             0
# 4  american world war ii base will be rebuilt as ...   RC    R             0
#
#                                            head_char
# 0        gulfport energy ceo steps down after review
# 1                       corrections & amplifications
# 2  in pittsburgh pcomma preparing to sit shiva fo...
# 3  university system of maryland board chairman r...
# 4  american world war ii base will be rebuilt as ...

# %%
sep_headlines.append(onion_df)
sep_headlines.insert((len(sep_headlines)-5), wsj_df)
sep_headlines.insert(1, huffpo_df)

# %%
L2R_headlines = pd.concat(sep_headlines)
L2R_headlines.head()
# Out:
#                                                  title publication  \
# 31584      Istanbul attack: Dozens killed at nightclub         CNN
# 31585     Alabama, Clemson back in national title game         CNN
# 31586               New year celebrations ring in 2017         CNN
# 31587  Trump says he has inside information on hacking         CNN
# 31588            3 dead in Texas plane crash collision         CNN
#
#                                               headline bias lean  \
# 31584      istanbul attack: dozens killed at nightclub   LL    L
# 31585     alabama, clemson back in national title game   LL    L
# 31586               new year celebrations ring in 2017   LL    L
# 31587  trump says he has inside information on hacking   LL    L
# 31588            3 dead in texas plane crash collision   LL    L
#
#        is_sarcastic                                          head_char
# 31584             0  istanbul attack pcolon dozens killed at nightclub
# 31585             0  alabama pcomma clemson back in national title ...
# 31586             0                 new year celebrations ring in 2017
# 31587             0    trump says he has inside information on hacking
# 31588             0              3 dead in texas plane crash collision

# %%
L2R_headlines.to_csv('combined_headlines.csv', index=False)

# %%
L2R_headlines['publication'].unique()
# Out:
# array(['CNN', 'Huffington Post', 'Vox', 'Atlantic', 'Business Insider',
#        'Buzzfeed News', 'Guardian', 'NPR', 'New York Times', 'Reuters',
#        'Talking Points Memo', 'Washington Post', 'New York Post', 'WSJ',
#        'Daily Wire', 'Fox News', 'National Review', 'Breitbart',
#        'The Onion'], dtype=object)
